# %%
import pandas as pd
df = pd.read_csv('data/electronic-card-transactions-october-2024-csv-tables.csv', index_col='Series_reference')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('data/electronic-card-transactions-october-2024-csv-tables.csv', index_col='Series_reference')
#
# ...

# %%
df.shape
# Out:
# (20850, 14)

# %%
df
# Out:
#                    Period  Data_value  Suppressed STATUS    UNITS  Magnitude  \
# Series_reference
# ECTA.S19A1        2001.03      2462.5         NaN      F  Dollars          6
# ECTA.S19A1        2002.03     17177.2         NaN      F  Dollars          6
# ECTA.S19A1        2003.03     22530.5         NaN      F  Dollars          6
# ECTA.S19A1        2004.03     28005.1         NaN      F  Dollars          6
# ECTA.S19A1        2005.03     30629.6         NaN      F  Dollars          6
# ...                   ...         ...         ...    ...      ...        ...
# ECTQ.S4AXP        2023.09        33.2         NaN      F  Percent          0
# ECTQ.S4AXP        2023.12        32.7         NaN      F  Percent          0
# ECTQ.S4AXP        2024.03        32.1         NaN      F  Percent          0
# ECTQ.S4AXP        2024.06        33.3         NaN      F  Percent          0
# ECTQ.S4AXP        2024.09        33.2         NaN      F  Percent          0
#
# ...

# %%
# info method gives number of rows and columns as well the columns datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20850 entries, 0 to 20849
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  20850 non-null  object
#  1   Period            20850 non-null  float64
#  2   Data_value        19729 non-null  float64
#  3   Suppressed        0 non-null      float64
#  4   STATUS            20850 non-null  object
#  5   UNITS             20850 non-null  object
#  6   Magnitude         20850 non-null  int64
#  7   Subject           20850 non-null  object
#  8   Group             20850 non-null  object
#  9   Series_title_1    20850 non-null  object
#  10  Series_title_2    20850 non-null  object
#  11  Series_title_3    4086 non-null   object
#  12  Series_title_4    0 non-null      float64
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 2.2+ MB

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03      2462.5         NaN      F  Dollars
# 1       ECTA.S19A1  2002.03     17177.2         NaN      F  Dollars
# 2       ECTA.S19A1  2003.03     22530.5         NaN      F  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
df.tail()
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 20845       ECTQ.S4AXP  2023.09        33.2         NaN      F  Percent
# 20846       ECTQ.S4AXP  2023.12        32.7         NaN      F  Percent
# 20847       ECTQ.S4AXP  2024.03        32.1         NaN      F  Percent
# 20848       ECTQ.S4AXP  2024.06        33.3         NaN      F  Percent
# 20849       ECTQ.S4AXP  2024.09        33.2         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# 20845          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20846          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20847          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20848          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20849          0  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# ...

# %%
df.columns
# Out:
# Index(['Period', 'Data_value', 'Suppressed', 'STATUS', 'UNITS', 'Magnitude',
#        'Subject', 'Group', 'Series_title_1', 'Series_title_2',
#        'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df.loc['ECTQ.S4AXP', 'Group']
# Out:
# Series_reference
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
#                                     ...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# ECTQ.S4AXP    Electronic card transactions by mean and propo...
# Name: Group, Length: 99, dtype: object
